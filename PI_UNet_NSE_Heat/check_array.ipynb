# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
data = np.load('/home/hero/Git/2402_pinn_dry/PI_UNet_NSE_Heat/example/figure/heat_bc.npy')
geom = pd.read_csv('df_geom_resized.csv',header=None)

# %%
data.shape, geom.shape
# Out:
# ((1, 1, 128, 256), (128, 256))

# %%
pd.DataFrame(data.squeeze())
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.001617  0.017714 -0.001124  0.018073 -0.000958  0.020288 -0.001195
# 1    0.000000  0.015401  0.000505  0.016063  0.007581  0.015707  0.006481
# 2    0.000000  0.007911  0.002007  0.007944  0.006137  0.008804  0.008067
# 3    0.000000  0.000274  0.001152  0.000647  0.004315  0.001420  0.005943
# 4    0.000000 -0.002910  0.000045 -0.002888  0.000040 -0.002050  0.000182
# ..        ...       ...       ...       ...       ...       ...       ...
# 123  0.000000  0.004543  0.000527  0.004414  0.001652  0.004001  0.003001
# 124  0.000000  0.008647  0.000937  0.008684  0.003786  0.009419  0.005690
# 125  0.000000  0.013863  0.003872  0.014064  0.008806  0.016957  0.009868
# 126  0.000000  0.042131  0.001931  0.028547  0.029956  0.017455  0.027919
# 127  0.052739  0.054661  0.050161  0.051893  0.049012  0.039998  0.050242
#
#           7         8         9    ...       246       247       248  \
# ...

# %%
# 히트맵 그리기 함수
def plot_heatmap(matrix):
    # 히트맵 생성
    plt.figure(figsize=(10, 5))
    #ax = sns.heatmap(matrix, annot=True, fmt=".0f", cmap='viridis')
    ax = sns.heatmap(matrix, cmap='coolwarm',vmin=-1,vmax=1)

    plt.show()
# 히트맵 그리기
#plot_heatmap(matrix)

# %%
plot_heatmap((data.squeeze())*geom)

# %%
data[:,144]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data[:,144]
#
# IndexError: index 144 is out of bounds for axis 1 with size 1
