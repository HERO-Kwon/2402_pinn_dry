# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
data = np.load('/home/hero/Git/2402_pinn_dry/PI_UNet_NSE_Heat/example/figure/heat_bc.npy')
geom = pd.read_csv('df_geom_resized.csv',header=None)

# %%
data.shape, geom.shape
# Out:
# ((1, 1, 128, 256), (128, 256))

# %%
pd.DataFrame(data.squeeze())
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.024011 -0.254841 -0.186409 -0.173058 -0.117313 -0.160137 -0.120985
# 1    0.000000 -0.354524 -0.127214  0.118004  0.173253  0.259667  0.276930
# 2    0.000000 -0.270383 -0.065039  0.167408  0.218732  0.277529  0.301192
# 3    0.000000  0.025947  0.132640  0.246672  0.277982  0.293479  0.309133
# 4    0.000000  0.039481  0.146335  0.214383  0.231538  0.244094  0.256335
# ..        ...       ...       ...       ...       ...       ...       ...
# 123  0.000000  0.214856  0.269609  0.226396  0.217060  0.156253  0.143141
# 124  0.000000  0.116876  0.220724  0.235604  0.238012  0.234668  0.233182
# 125  0.000000  0.474938  0.675375  0.630134  0.619304  0.574950  0.581386
# 126  0.000000  0.357863  0.527496  0.518533  0.530905  0.565425  0.597528
# 127  0.232746  0.379350  0.468950  0.534373  0.566483  0.672395  0.698977
#
#           7         8         9    ...       246       247       248  \
# 0   -0.139737 -0.147717 -0.207247  ... -0.174318 -0.164866 -0.183188
# 1    0.288261  0.266073  0.257100  ...  0.239894  0.200180  0.174644
# 2    0.309932  0.297325  0.287079  ...  0.260094  0.233244  0.226491
# 3    0.301883  0.300615  0.304294  ...  0.280746  0.278567  0.279533
# 4    0.252332  0.254186  0.267698  ...  0.280697  0.269022  0.264343
# ..        ...       ...       ...  ...       ...       ...       ...
# 123  0.153356  0.140603  0.129411  ...  0.146730  0.166075  0.185189
# 124  0.239965  0.219315  0.211938  ...  0.215715  0.234605  0.264051
# 125  0.548033  0.516704  0.494169  ...  0.483027  0.534251  0.554260
# 126  0.581355  0.563459  0.554039  ...  0.579505  0.642109  0.652476
# 127  0.742547  0.727366  0.748546  ...  0.748103  0.715467  0.731040
#
#           249       250       251       252       253       254       255
# 0   -0.076301 -0.102893 -0.157710 -0.162383  0.016082  0.057596  0.319353
# 1    0.163612  0.119344 -0.053127 -0.159213 -0.203550 -0.082067  0.034768
# 2    0.220566  0.186514  0.013828 -0.048003 -0.088554 -0.055882 -0.040469
# 3    0.269522  0.240657  0.161640  0.055685 -0.010914  0.023171 -0.057365
# 4    0.261339  0.233229  0.165266  0.095649  0.053711  0.063326  0.032435
# ..        ...       ...       ...       ...       ...       ...       ...
# 123  0.207545  0.180216  0.177915  0.185457  0.159408  0.145383  0.151168
# 124  0.281520  0.275432  0.263155  0.258576  0.191386  0.138548  0.213686
# 125  0.589939  0.592337  0.612892  0.591104  0.496722  0.340280  0.377875
# 126  0.697099  0.687088  0.722660  0.646980  0.536993  0.413613  0.550858
# 127  0.708503  0.680502  0.635436  0.552338  0.369960  0.304469  0.088796
#
# [128 rows x 256 columns]

# %%
# 히트맵 그리기 함수
def plot_heatmap(matrix):
    # 히트맵 생성
    plt.figure(figsize=(10, 5))
    #ax = sns.heatmap(matrix, annot=True, fmt=".0f", cmap='viridis')
    ax = sns.heatmap(matrix, cmap='coolwarm',vmin=0,vmax=10)

    plt.show()
# 히트맵 그리기
#plot_heatmap(matrix)

# %%
plot_heatmap((data.squeeze()[:,:]))

# %%
data[:,144]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data[:,144]
#
# IndexError: index 144 is out of bounds for axis 1 with size 1
