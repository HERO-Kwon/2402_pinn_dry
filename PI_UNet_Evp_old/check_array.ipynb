# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
data = np.load('/home/hero/Git/2402_pinn_dry/PI_UNet_NSE/example/figure/g_bc_sum.npy')

# %%
data = data.squeeze()

# %%
# 히트맵 그리기 함수
def plot_heatmap(matrix):
    # 히트맵 생성
    plt.figure(figsize=(10, 5))
    #ax = sns.heatmap(matrix, annot=True, fmt=".0f", cmap='viridis')
    ax = sns.heatmap(matrix, cmap='viridis')

    plt.show()
# 히트맵 그리기
#plot_heatmap(matrix)

# %%
plot_heatmap(data[1,:,:])

# %%
data[1,:,:]
# Out:
# array([[60., 60., 60., ..., 60., 60., 60.],
#        [60., 60., 60., ..., 60., 60., 61.],
#        [60., 60., 61., ..., 61., 61., 61.],
#        ...,
#        [60., 60., 61., ..., 61., 61., 61.],
#        [60., 60., 60., ..., 60., 60., 61.],
#        [60., 60., 60., ..., 60., 60., 60.]], dtype=float32)
