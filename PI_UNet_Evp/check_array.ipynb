# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
data = np.load('/home/hero/Git/2402_pinn_dry/PI_UNet_NSE_Heat/example/figure/heat_bc.npy')
geom = pd.read_csv('df_geom_resized.csv',header=None)

# %%
data.shape, geom.shape
# Out:
# ((1, 1, 128, 256), (128, 256))

# %%
pd.DataFrame(data.squeeze())
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000105  0.000205  0.000349  0.000523  0.000703  0.000877  0.001101
# 1    0.000000  0.000151  0.000317  0.000470  0.000640  0.000819  0.001045
# 2    0.000000  0.000105  0.000273  0.000417  0.000579  0.000755  0.000983
# 3    0.000000  0.000086  0.000256  0.000375  0.000534  0.000708  0.000930
# 4    0.000000  0.000060  0.000221  0.000332  0.000485  0.000662  0.000880
# ..        ...       ...       ...       ...       ...       ...       ...
# 123  0.000000 -0.000056 -0.000005  0.000070  0.000158  0.000263  0.000409
# 124  0.000000 -0.000052  0.000006  0.000091  0.000174  0.000282  0.000424
# 125  0.000000 -0.000054  0.000020  0.000096  0.000175  0.000265  0.000404
# 126  0.000000 -0.000021  0.000039  0.000104  0.000182  0.000278  0.000404
# 127  0.000021  0.000030  0.000091  0.000158  0.000233  0.000335  0.000457
#
#           7         8         9    ...        246        247        248  \
# 0    0.001344  0.001623  0.001914  ...  20.186991  20.195997  20.203770
# 1    0.001288  0.001561  0.001841  ...  20.187263  20.196220  20.203997
# 2    0.001221  0.001493  0.001769  ...  20.188278  20.197212  20.205013
# 3    0.001150  0.001412  0.001687  ...  20.190565  20.199425  20.207102
# 4    0.001088  0.001336  0.001597  ...  20.194090  20.202816  20.210503
# ..        ...       ...       ...  ...        ...        ...        ...
# 123  0.000528  0.000675  0.000825  ...  14.326611  14.346600  14.364431
# 124  0.000539  0.000684  0.000834  ...  14.318983  14.338887  14.356737
# 125  0.000544  0.000686  0.000843  ...  14.313756  14.333576  14.351323
# 126  0.000532  0.000678  0.000833  ...  14.310860  14.330637  14.348327
# 127  0.000575  0.000716  0.000870  ...  14.309976  14.329748  14.347414
#
#            249        250        251        252        253        254  \
# 0    20.210592  20.216309  20.220978  20.224651  20.227345  20.228876
# 1    20.210812  20.216545  20.221230  20.225029  20.227732  20.229258
# 2    20.211712  20.217445  20.222128  20.225929  20.228857  20.230350
# 3    20.213881  20.219629  20.224426  20.228210  20.231136  20.232811
# 4    20.217222  20.222988  20.227732  20.231508  20.234394  20.236107
# ..         ...        ...        ...        ...        ...        ...
# 123  14.380086  14.393494  14.404745  14.413672  14.420344  14.424256
# 124  14.372342  14.385661  14.396774  14.405529  14.412036  14.415838
# 125  14.366817  14.380068  14.391018  14.399699  14.406027  14.409853
# 126  14.363711  14.376920  14.387806  14.396340  14.402689  14.406497
# 127  14.362824  14.376026  14.386907  14.395432  14.401575  14.405298
#
#            255
# 0    20.229279
# 1    20.229784
# 2    20.231085
# 3    20.233421
# 4    20.236753
# ..         ...
# 123  14.425597
# 124  14.417164
# 125  14.411166
# 126  14.407784
# 127  14.406492
#
# [128 rows x 256 columns]

# %%
# 히트맵 그리기 함수
def plot_heatmap(matrix):
    # 히트맵 생성
    plt.figure(figsize=(10, 5))
    #ax = sns.heatmap(matrix, annot=True, fmt=".0f", cmap='viridis')
    ax = sns.heatmap(matrix, cmap='coolwarm',vmin=0,vmax=30)

    plt.show()
# 히트맵 그리기
#plot_heatmap(matrix)

# %%
plot_heatmap((data.squeeze()))

# %%
data[:,144]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data[:,144]
#
# IndexError: index 144 is out of bounds for axis 1 with size 1
